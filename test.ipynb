# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
df = pd.DataFrame({
    "id" : np.arange(10),
    "name" : np.random.choice(['alex', 'tim', 'ed', 'selena'], size=10)
})

df
# Out:
#    id    name
# 0   0  selena
# 1   1     tim
# 2   2    alex
# 3   3      ed
# 4   4     tim
# 5   5    alex
# 6   6      ed
# 7   7  selena
# 8   8      ed
# 9   9    alex

# %%
plt.plot(np.arange(-5, 5, 0.2), np.tanh(np.arange(-5, 5, 0.2))); plt.grid()

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model
# Out:
# LogisticRegression()
